# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as  plt

# %%
data=pd.read_csv('car_price.csv')

# %%
data[:5]
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   object
#  1   year           8128 non-null   int64
#  2   selling_price  8128 non-null   int64
#  3   km_driven      8128 non-null   int64
#  4   fuel           8128 non-null   object
#  5   seller_type    8128 non-null   object
#  6   transmission   8128 non-null   object
#  7   owner          8128 non-null   object
#  8   mileage        7907 non-null   object
#  9   engine         7907 non-null   object
#  10  max_power      7913 non-null   object
#  11  torque         7906 non-null   object
#  12  seats          7907 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 825.6+ KB

# %%
data['name'].head()
# Out:
# 0          Maruti Swift Dzire VDI
# 1    Skoda Rapid 1.5 TDI Ambition
# 2        Honda City 2017-2020 EXi
# 3       Hyundai i20 Sportz Diesel
# 4          Maruti Swift VXI BSIII
# Name: name, dtype: object

# %%
s=set(data['name'].iloc())
len(s)
# Out:
# 2058

# %%
data['name'].value_counts()
# Out:
# Maruti Swift Dzire VDI                   129
# Maruti Alto 800 LXI                       82
# Maruti Alto LXi                           71
# BMW X4 M Sport X xDrive20d                62
# Maruti Swift VDI                          61
#                                         ...
# Renault Lodgy 85PS RxL                     1
# Mercedes-Benz GL-Class 350 CDI Luxury      1
# Maruti Ertiga LDI                          1
# Honda Accord 2.4 M/T                       1
# Maruti Dzire LXI                           1
# Name: name, Length: 2058, dtype: int64

# %%
data['km_driven'].mean()
# Out:
# 69819.51082677166

# %%
data.mean()
# Out:
# year               2013.804011
# selling_price    638271.807702
# km_driven         69819.510827
# seats                 5.416719
# dtype: float64

# %%
data.loc[:,"name":"km_driven"]
# Out:
#                               name  year  selling_price  km_driven
# 0           Maruti Swift Dzire VDI  2014         450000     145500
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2         Honda City 2017-2020 EXi  2006         158000     140000
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000
# 4           Maruti Swift VXI BSIII  2007         130000     120000
# ...                            ...   ...            ...        ...
# 8123             Hyundai i20 Magna  2013         320000     110000
# 8124         Hyundai Verna CRDi SX  2007         135000     119000
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000
# 8126               Tata Indigo CR4  2013         290000      25000
# 8127               Tata Indigo CR4  2013         290000      25000
#
# [8128 rows x 4 columns]

# %%
data1=data.pivot_table(['km_driven'],['name']).sort_values(by='km_driven',ascending=False)
data1
# Out:
#                                                km_driven
# name
# Toyota Innova 2.5 EV Diesel PS 7 Seater BSIII   500000.0
# Toyota Innova 2.5 VX (Diesel) 7 Seater BS IV    426000.0
# Mahindra Bolero DI Non AC BSIII                 300000.0
# Toyota Qualis FS B3                             290000.0
# Tata Sumo Gold GX BSIII                         270000.0
# ...                                                  ...
# MG Hector Sharp DCT Dualtone                      1600.0
# Datsun RediGO SV 1.0                              1300.0
# Honda City i-VTEC CVT V                           1000.0
# Toyota Innova Crysta 2.4 ZX AT                    1000.0
# Maruti Eeco 5 STR With AC Plus HTR CNG               1.0
#
# [2058 rows x 1 columns]

# %%
sns.countplot(x="km_driven", data=data1)
plt.show()

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(data.km_driven,data.selling_price,marker='*')
plt.show()

# %%
import seaborn as sns

# %%
data.isnull().sum()
# Out:
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          221
# engine           221
# max_power        215
# torque           222
# seats            221
# dtype: int64

# %%
data.describe()
# Out:
#               year  selling_price     km_driven        seats
# count  8128.000000   8.128000e+03  8.128000e+03  7907.000000
# mean   2013.804011   6.382718e+05  6.981951e+04     5.416719
# std       4.044249   8.062534e+05  5.655055e+04     0.959588
# min    1983.000000   2.999900e+04  1.000000e+00     2.000000
# 25%    2011.000000   2.549990e+05  3.500000e+04     5.000000
# 50%    2015.000000   4.500000e+05  6.000000e+04     5.000000
# 75%    2017.000000   6.750000e+05  9.800000e+04     5.000000
# max    2020.000000   1.000000e+07  2.360457e+06    14.000000

# %%
#data=data.fillna(method='pad')
data=data.dropna()

# %%
data.isnull().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# mileage          0
# engine           0
# max_power        0
# torque           0
# seats            0
# dtype: int64

# %%
data.describe()
# Out:
#               year  selling_price     km_driven        seats
# count  7906.000000   7.906000e+03  7.906000e+03  7906.000000
# mean   2013.983936   6.498137e+05  6.918866e+04     5.416393
# std       3.863695   8.135827e+05  5.679230e+04     0.959208
# min    1994.000000   2.999900e+04  1.000000e+00     2.000000
# 25%    2012.000000   2.700000e+05  3.500000e+04     5.000000
# 50%    2015.000000   4.500000e+05  6.000000e+04     5.000000
# 75%    2017.000000   6.900000e+05  9.542500e+04     5.000000
# max    2020.000000   1.000000e+07  2.360457e+06    14.000000

# %%
from sklearn.preprocessing import LabelEncoder

# %%
data[:5]
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# ...

# %%
fuel=LabelEncoder()
data1=data

# %%
data1[:5]
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# ...

# %%
data1['fuel']=fuel.fit_transform(data1['fuel'])
data1['seller_type']=fuel.fit_transform(data1['seller_type'])
data1['transmission']=fuel.fit_transform(data1['transmission'])
data1['owner']=fuel.fit_transform(data1['owner'])
data1['torque']=fuel.fit_transform(data1['torque'])
data1[:20]
# Out:
#                                     name  year  selling_price  km_driven  \
# 0                 Maruti Swift Dzire VDI  2014         450000     145500
# 1           Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2               Honda City 2017-2020 EXi  2006         158000     140000
# 3              Hyundai i20 Sportz Diesel  2010         225000     127000
# 4                 Maruti Swift VXI BSIII  2007         130000     120000
# 5          Hyundai Xcent 1.2 VTVT E Plus  2017         440000      45000
# 6           Maruti Wagon R LXI DUO BSIII  2007          96000     175000
# 7                     Maruti 800 DX BSII  2001          45000       5000
# 8                       Toyota Etios VXD  2011         350000      90000
# 9   Ford Figo Diesel Celebration Edition  2013         200000     169000
# 10       Renault Duster 110PS Diesel RxL  2014         500000      68000
# 11                         Maruti Zen LX  2005          92000     100000
# ...

# %%
data.owner.nunique()
# Out:
# 5

# %%
set(data.owner.tolist())
# Out:
# {0, 1, 2, 3, 4}

# %%
data['mileage'].tolist()[:5]
# Out:
# ['23.4 kmpl', '21.14 kmpl', '17.7 kmpl', '23.0 kmpl', '16.1 kmpl']

# %%
data.dtypes
# Out:
# name              object
# year               int64
# selling_price      int64
# km_driven          int64
# fuel               int64
# seller_type        int64
# transmission       int64
# owner              int64
# mileage           object
# engine            object
# max_power         object
# torque             int64
# seats            float64
# dtype: object

# %%
def change(x):
    x=str(x).split()
    return float(x[0])

# %%
data1
# Out:
#                               name  year  selling_price  km_driven  fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500     1
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000     1
# 2         Honda City 2017-2020 EXi  2006         158000     140000     3
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000     1
# 4           Maruti Swift VXI BSIII  2007         130000     120000     3
# ...                            ...   ...            ...        ...   ...
# 8123             Hyundai i20 Magna  2013         320000     110000     3
# 8124         Hyundai Verna CRDi SX  2007         135000     119000     1
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000     1
# 8126               Tata Indigo CR4  2013         290000      25000     1
# 8127               Tata Indigo CR4  2013         290000      25000     1
#
#       seller_type  transmission  owner     mileage   engine   max_power  \
# ...

# %%
data1['mileage']=data1['mileage'].apply(change)
data1[:5]
# Out:
#                            name  year  selling_price  km_driven  fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500     1
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000     1
# 2      Honda City 2017-2020 EXi  2006         158000     140000     3
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000     1
# 4        Maruti Swift VXI BSIII  2007         130000     120000     3
#
#    seller_type  transmission  owner  mileage   engine   max_power  torque  \
# 0            1             1      0    23.40  1248 CC      74 bhp     177
# 1            1             1      2    21.14  1498 CC  103.52 bhp     259
# 2            1             1      4    17.70  1497 CC      78 bhp      66
# 3            1             1      0    23.00  1396 CC      90 bhp     223
# 4            1             1      0    16.10  1298 CC    88.2 bhp      21
#
#    seats
# 0    5.0
# 1    5.0
# 2    5.0
# 3    5.0
# 4    5.0

# %%
data1['engine']=data1['engine'].apply(change)
data1[:5]
# Out:
#                            name  year  selling_price  km_driven  fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500     1
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000     1
# 2      Honda City 2017-2020 EXi  2006         158000     140000     3
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000     1
# 4        Maruti Swift VXI BSIII  2007         130000     120000     3
#
#    seller_type  transmission  owner  mileage  engine   max_power  torque  \
# 0            1             1      0    23.40  1248.0      74 bhp     177
# 1            1             1      2    21.14  1498.0  103.52 bhp     259
# 2            1             1      4    17.70  1497.0      78 bhp      66
# 3            1             1      0    23.00  1396.0      90 bhp     223
# 4            1             1      0    16.10  1298.0    88.2 bhp      21
#
#    seats
# 0    5.0
# 1    5.0
# 2    5.0
# 3    5.0
# 4    5.0

# %%
data1['max_power']=data1['max_power'].apply(change)
data1[:5]
# Out:
#                            name  year  selling_price  km_driven  fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500     1
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000     1
# 2      Honda City 2017-2020 EXi  2006         158000     140000     3
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000     1
# 4        Maruti Swift VXI BSIII  2007         130000     120000     3
#
#    seller_type  transmission  owner  mileage  engine  max_power  torque  seats
# 0            1             1      0    23.40  1248.0      74.00     177    5.0
# 1            1             1      2    21.14  1498.0     103.52     259    5.0
# 2            1             1      4    17.70  1497.0      78.00      66    5.0
# 3            1             1      0    23.00  1396.0      90.00     223    5.0
# 4            1             1      0    16.10  1298.0      88.20      21    5.0

# %%
#checking for outliers

# %%
sns.boxplot(data=data1.year)
# Out:
# <AxesSubplot:>

# %%
data1=data1[~(data1['year'] <= 2005)]
sns.boxplot(data=data1.year)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data=data1.selling_price)
# Out:
# <AxesSubplot:>

# %%
data1=data1[~(data1['selling_price'] >= 1150000)]
sns.boxplot(data=data1.selling_price)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data=data1.km_driven)
# Out:
# <AxesSubplot:>

# %%
data1=data1[~(data1['km_driven'] >= 175000)]
sns.boxplot(data=data1.km_driven)
# Out:
# <AxesSubplot:>

# %%
data1[:5]
# Out:
#                            name  year  selling_price  km_driven  fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500     1
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000     1
# 2      Honda City 2017-2020 EXi  2006         158000     140000     3
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000     1
# 4        Maruti Swift VXI BSIII  2007         130000     120000     3
#
#    seller_type  transmission  owner  mileage  engine  max_power  torque  seats
# 0            1             1      0    23.40  1248.0      74.00     177    5.0
# 1            1             1      2    21.14  1498.0     103.52     259    5.0
# 2            1             1      4    17.70  1497.0      78.00      66    5.0
# 3            1             1      0    23.00  1396.0      90.00     223    5.0
# 4            1             1      0    16.10  1298.0      88.20      21    5.0

# %%
data1=data1[~(data1['mileage'] >30)]
data1=data1[~(data1['mileage'] <10)]
sns.boxplot(data=data1.mileage)
# Out:
# <AxesSubplot:>

# %%
data1=data1[~(data1['engine'] >1600)]
data1=data1[~(data1['engine'] <1000)]
sns.boxplot(data=data1.engine)
# Out:
# <AxesSubplot:>

# %%
data1[:5]
# Out:
#                            name  year  selling_price  km_driven  fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500     1
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000     1
# 2      Honda City 2017-2020 EXi  2006         158000     140000     3
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000     1
# 4        Maruti Swift VXI BSIII  2007         130000     120000     3
#
#    seller_type  transmission  owner  mileage  engine  max_power  torque  seats
# 0            1             1      0    23.40  1248.0      74.00     177    5.0
# 1            1             1      2    21.14  1498.0     103.52     259    5.0
# 2            1             1      4    17.70  1497.0      78.00      66    5.0
# 3            1             1      0    23.00  1396.0      90.00     223    5.0
# 4            1             1      0    16.10  1298.0      88.20      21    5.0

# %%
data1=data1[~(data1['max_power'] >110)]
data1=data1[~(data1['max_power'] <60)]
sns.boxplot(data=data1.max_power)
# Out:
# <AxesSubplot:>

# %%
data1=data1[~(data1['torque'] >300)]
sns.boxplot(data=data1.torque)
# Out:
# <AxesSubplot:>

# %%
data1.items
# Out:
# <bound method DataFrame.items of                               name  year  selling_price  km_driven  fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500     1
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000     1
# 2         Honda City 2017-2020 EXi  2006         158000     140000     3
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000     1
# 4           Maruti Swift VXI BSIII  2007         130000     120000     3
# ...                            ...   ...            ...        ...   ...
# 8123             Hyundai i20 Magna  2013         320000     110000     3
# 8124         Hyundai Verna CRDi SX  2007         135000     119000     1
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000     1
# 8126               Tata Indigo CR4  2013         290000      25000     1
# 8127               Tata Indigo CR4  2013         290000      25000     1
#
# ...

# %%
data1['name']=fuel.fit_transform(data1['name'])
data1[:5]
# Out:
#    name  year  selling_price  km_driven  fuel  seller_type  transmission  \
# 0   641  2014         450000     145500     1            1             1
# 1   803  2014         370000     120000     1            1             1
# 2   208  2006         158000     140000     3            1             1
# 3   427  2010         225000     127000     1            1             1
# 4   682  2007         130000     120000     3            1             1
#
#    owner  mileage  engine  max_power  torque  seats
# 0      0    23.40  1248.0      74.00     177    5.0
# 1      2    21.14  1498.0     103.52     259    5.0
# 2      4    17.70  1497.0      78.00      66    5.0
# 3      0    23.00  1396.0      90.00     223    5.0
# 4      0    16.10  1298.0      88.20      21    5.0

# %%
train_x=data1.drop(['selling_price'],axis=1)
train_x[:5]
# Out:
#    name  year  km_driven  fuel  seller_type  transmission  owner  mileage  \
# 0   641  2014     145500     1            1             1      0    23.40
# 1   803  2014     120000     1            1             1      2    21.14
# 2   208  2006     140000     3            1             1      4    17.70
# 3   427  2010     127000     1            1             1      0    23.00
# 4   682  2007     120000     3            1             1      0    16.10
#
#    engine  max_power  torque  seats
# 0  1248.0      74.00     177    5.0
# 1  1498.0     103.52     259    5.0
# 2  1497.0      78.00      66    5.0
# 3  1396.0      90.00     223    5.0
# 4  1298.0      88.20      21    5.0

# %%
train_y=data1['selling_price']
train_y
# Out:
# 0       450000
# 1       370000
# 2       158000
# 3       225000
# 4       130000
#          ...
# 8123    320000
# 8124    135000
# 8125    382000
# 8126    290000
# 8127    290000
# Name: selling_price, Length: 4108, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(train_x, train_y, test_size=0.3, random_state=42)

# %%
#data1['mileage']=data1['mileage'].apply(change)
X_train[:5]
# Out:
#       name  year  km_driven  fuel  seller_type  transmission  owner  mileage  \
# 106    159  2020       5000     3            1             1      2    19.00
# 2429   925  2018      25000     3            1             1      0    23.84
# 3621   321  2008     110000     1            1             1      2    18.10
# 2957   289  2018      25000     3            1             1      0    18.90
# 7937   512  2018      50000     1            1             1      0    27.39
#
#       engine  max_power  torque  seats
# 106   1194.0      94.68      67    5.0
# 2429  1199.0      84.00      49    5.0
# 3621  1493.0     110.00     249    5.0
# 2957  1197.0      81.86      36    5.0
# 7937  1248.0      74.00     177    5.0

# %%
y_train
# Out:
# 106     400000
# 2429    390000
# 3621    250000
# 2957    580000
# 7937    760000
#          ...
# 6773    850000
# 935     250000
# 6098    520000
# 7444    750000
# 1692    850000
# Name: selling_price, Length: 2875, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train,y_train)
lr.score(X_test,y_test)
# Out:
# 0.7461981526396433

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

pipeline = make_pipeline(PolynomialFeatures(2), LinearRegression())
pipeline.fit(np.array(X_train),y_train)
# Out:
# Pipeline(steps=[('polynomialfeatures', PolynomialFeatures()),
#                 ('linearregression', LinearRegression())])

# %%
pipeline.score(np.array(X_test),y_test)
# Out:
# 0.8043309290178274

# %%
y_pred=pipeline.predict(np.array(X_test))

# %%
X_test.shape
X_test
# Out:
#       name  year  km_driven  fuel  seller_type  transmission  owner  mileage  \
# 4666   389  2015      70000     3            1             1      4    17.19
# 7111   641  2014      70000     1            1             1      1    23.40
# 5405    10  2013      37000     3            0             1      0    13.70
# 4471   368  2018      60000     1            1             1      2    22.54
# 1380    90  2017      63982     1            0             1      0    22.70
# ...    ...   ...        ...   ...          ...           ...    ...      ...
# 2298   242  2019       1500     3            1             0      0    18.20
# 2864   294  2019      13000     3            1             1      0    18.90
# 7390   628  2017      80000     1            1             0      0    28.40
# 420    985  2017      25538     3            2             1      0    16.78
# 3866   703  2019      35000     1            1             0      0    24.30
#
#       engine  max_power  torque  seats
# ...

# %%
y_test.shape
y_test
# Out:
# 4666    590000
# 7111    459999
# 5405    350000
# 4471    799000
# 1380    850000
#          ...
# 2298    840000
# 2864    570000
# 7390    700000
# 420     625000
# 3866    860000
# Name: selling_price, Length: 1233, dtype: int64

# %%
plt.scatter(X_test.km_driven,y_test,color='black')
plt.plot(X_test,y_pred,color='red')
plt.show()

# %%
out=lr.predict(X_test)

# %%
plt.scatter(X_test.km_driven,y_test,color='black')
plt.plot(X_test,out,color='red')
plt.show()

# %%
from sklearn.metrics import mean_absolute_error
mae=mean_absolute_error(y_test,y_pred)

# %%
mae
# Out:
# 70595.69826048134

# %%
mae1=mean_absolute_error(y_test,out)

# %%
mae1
# Out:
# 83515.19393624096

# %%
pipeline.score(X_test,y_test)
# Out:
# 0.8043309290178274
